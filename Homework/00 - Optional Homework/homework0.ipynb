# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
data = pd.read_csv('./data/interactive_data.csv', sep=',')
data = data.drop(columns = 'Unnamed: 0')

# %%
data
# Out:
#             Intent         Gender            Age                    Race  \
# 0    None selected  None selected  None selected           None selected
# 1    None selected  None selected  None selected                   White
# 2    None selected  None selected  None selected                   Black
# 3    None selected  None selected  None selected                Hispanic
# 4    None selected  None selected  None selected  Asian/Pacific Islander
# ..             ...            ...            ...                     ...
# 535        Unknown           Male              5                   White
# 536        Unknown           Male              5                   Black
# 537        Unknown           Male              5                Hispanic
# 538        Unknown           Male              5  Asian/Pacific Islander
# 539        Unknown           Male              5                   Other
#
#      Deaths  Population  Rate
# 0     33599   316299978  10.6
# ...

# %%
suicide = data[data['Intent'] == 'Suicide'].reset_index(drop=True)
suicide
# Out:
#       Intent         Gender            Age                    Race  Deaths  \
# 0    Suicide  None selected  None selected           None selected   21058
# 1    Suicide  None selected  None selected                   White   18457
# 2    Suicide  None selected  None selected                   Black    1111
# 3    Suicide  None selected  None selected                Hispanic    1057
# 4    Suicide  None selected  None selected  Asian/Pacific Islander     248
# ..       ...            ...            ...                     ...     ...
# 103  Suicide           Male              5                   White       1
# 104  Suicide           Male              5                   Black       0
# 105  Suicide           Male              5                Hispanic       0
# 106  Suicide           Male              5  Asian/Pacific Islander       0
# 107  Suicide           Male              5                   Other       0
#
#      Population  Rate
# 0     316299978   6.7
# ...
